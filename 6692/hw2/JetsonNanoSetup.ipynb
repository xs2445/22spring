# %% [markdown]
# # Lab - JetsonNanoSetup-PretrainedDeployment
# ## E6692 Spring 2022

# %% [markdown]
# ## Part 1: Jetson Nano Setup
#
# In this part you will verify your Jetson Nano and computing environment setup.
#
# After completing the [Jetson Nano setup guide](https://github.com/eecse6692/e6692_2022Spring_students_repo/tree/main/Lab-JetsonNanoSetup-PretrainedDeployment/JetsonNanoSetup), run the following cells in Jupyter Lab with the docker mounted and insert screenshots where indicated.

# %%
# import packages

import tensorflow
import torch
import torchvision
import torchaudio
import onnx
import cupy
import numpy
import numba
import cv2
import pandas
import scipy
import sklearn
# Out:
# WARNING:tensorflow:Deprecation warnings have been disabled. Set TF_ENABLE_DEPRECATION_WARNINGS=1 to re-enable them.
# /usr/local/lib/python3.6/dist-packages/torchaudio-0.9.0a0+33b2469-py3.6-linux-aarch64.egg/torchaudio/backend/utils.py:67: UserWarning: No audio backend is available.
#   warnings.warn('No audio backend is available.')

# %% [markdown]
# It's OK if you see a depreciation warning from TensorFlow and an audio backend warning from torchaudio.

# %%
# verify package versions

print("TensorFlow version 1.15.5:\t", '1.15.5' == tensorflow.__version__)
print("PyTorch version 1.9.0:\t\t", '1.9.0' == torch.__version__)
print("torchvision 0.10.0:\t\t", '0.10.0a0+300a8a4' == torchvision.__version__)
print("torchaudio 0.9.0:\t\t", '0.9.0a0+33b2469' == torchaudio.__version__)
print("ONNX version 1.10.1:\t\t", '1.10.1' == onnx.__version__)
print("CuPy version 9.2.0:\t\t", '9.2.0' == cupy.__version__)
print("NumPy version 1.19.5:\t\t", '1.19.5' == numpy.__version__)
print("Numba version 0.53.1:\t\t", '0.53.1' == numba.__version__)
print("OpenCV version 4.5.0:\t\t", '4.5.0' == cv2.__version__)
print("Pandas version 1.1.5:\t\t", '1.1.5' == pandas.__version__)
print("SciPy version 1.5.4:\t\t", '1.5.4' == scipy.__version__)
print("Scikit-Learn version 0.24.2:\t", '0.24.2' == sklearn.__version__)

# %% [markdown]
# All versions should show "True".

# %%
# check CUDA enabled and GPU name

print("CUDA enabled:\t", torch.cuda.is_available())
print("GPU:\t\t", torch.cuda.get_device_name(0))

# %% [markdown]
# CUDA should be enabled and it should read the name of the Jetson Nano GPU: "NVIDIA Tegra X1".

# %%
# check CUDA compiler version
# !nvcc -V

# %% [markdown]
# You should see the following:
#
# ![Screen Shot 2022-01-19 at 11.56.13 AM.png](attachment:f2d49de2-9a60-499c-99e1-fe0df1a43d87.png)

# %% [markdown]
# ### TODO: insert screenshot of terminal with docker mounted
#
# Here is an example:
# ![Screen Shot 2022-01-19 at 12.05.14 PM.png](attachment:2cd2a444-acee-40a5-ab8c-8abe6cd8c8e8.png)
#
# Replace the example with your own screenshot.

# %% [markdown]
# #### TODO: insert screenshot of JupyterLab with Jetson Nano IP in browser
#
# Example:
# ![Screen Shot 2022-01-19 at 12.08.25 PM.png](attachment:2dc01095-df58-438e-a5e3-667439bc3701.png)
